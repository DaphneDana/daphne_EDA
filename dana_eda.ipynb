# %%
# %cd /content
# Out:
# /content

# %%
# !git clone https://github.com/DaphneDana/daphne_EDA.git
# Out:
# Cloning into 'daphne_EDA'...
# ...

# %%
# %cd /content/daphne_EDA
# Out:
# /content/daphne_EDA

# %%
# If your notebook is in /content, move it into the repo
# !mv /content/dana_eda.ipynb /content/my-colab-notebooks/
# Out:
# mv: cannot stat '/content/dana_eda.ipynb': No such file or directory
